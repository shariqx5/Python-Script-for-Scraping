# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import pandas as pd

# %%
from lxml import html
import json
payload={
    "txtUsername":"ShakeelUae",
    "txtPassword":"ShakeelUae123"
  
}


dashboardurl='http://hamarideals.pk/hd_oms/admin/frmMain.php'

session=requests.session()
login_url="http://hamarideals.pk/hd_oms/admin/frmLogin.php"

result=session.post(login_url,json=json.dumps(payload))
loginresult=BeautifulSoup(result.content,'html.parser')
print(loginresult.text)
afterpage=session.get(dashboardurl)
print(afterpage.text)
# Out:
# BARTZMALL
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Login to your account
#
#
# Enter your username and password.
#
#
# Username
#
#
#
#
#
#
#
# Password
#
#
#
#
#
#
#
# 					Login
#
#
#
# Forgot your password ?
#
# 				   no worries, click here
# 				   to reset your password.
#
#
#
#
# Forget Password ?
# Enter your e-mail address below to reset your password.
#
#
#
#
#
#
#
#
#  Back
#
#
# 					Submit
#
#
#
#
#
# 	  Copyright © 2016 EnomSoftCloud Computing Division
#
#
#
#
#
# Modal Title
#
#
#
#
#
#
#
#
#
#
# Modal Title
#
#
#
#
#
#
# Close
#
#
#
#
#
#
#
# Full Width
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Session Time
#
#
#
# Type:
#
#
# Break
#
#
#
#
#
# Break Type:
#
#
# Please Select
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Close
#  Save
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Session Time
#
#
#
# Un-Break:
#
#
# Un-Break
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Save
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	$(document).ready(function() {
# 		App.init();
# ...

# %%
from selenium import webdriver
driver=webdriver.Chrome("G:\\chromedriver\\chromedriver.exe")

# %%
driver.get("http://hamarideals.pk/hd_oms/admin/frmLogin.php")

# %%
username=driver.find_element_by_id("txtUsername")
username.clear()
username.send_keys('ShakeelUae')

password=driver.find_element_by_id("txtPassword")
password.clear()
password.send_keys("ShakeelUae123")

button=driver.find_element_by_id("btn_login")
button.click()

# %%
#navigating to the page where we need to extract out text
# firstLink=driver.find_element_by_xpath("//a[@href='order_grid.php']")
driver.get("http://hamarideals.pk/hd_oms/admin/order_grid.php?per_page=100")

# %%
page_source=driver.page_source

# %%
from bs4 import BeautifulSoup as bs4

# %%
page_content=bs4(page_source,'lxml')

# %%
#extracting table data
productsData=[]
# for tr in page_content.select("#orderlist table tr"):
#     print(tr)
#     productsData.append(tr.select("td:nth-of-type(3)"))
    
for row in page_content.findAll('table')[2].tbody.findAll('tr'):
    third_column = row.findAll('td')[2].text
    productsData.append(third_column)

# %%
import xlsxwriter as excel
workbook=excel.Workbook('file.xlsx')
worksheet=workbook.add_worksheet()
row=0
column=0

for item in productsData:
    worksheet.write(row,column,item)
    row+=1
workbook.close()

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-97-ad0c9a213c39> in <module>
# ----> 1 driver.close()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
# ...
